# %% [markdown]
# <a href="https://colab.research.google.com/github/MauriceChiu7/cs593-rob-project/blob/mar24/colab_A1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pybullet

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir("/content/drive/MyDrive/Colab Notebooks/cs593-rob-project/unitree_pybullet")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import generateDataA1

# %%
start = 190
end = 208

print(f"\ngenerating paths {start} to {end}...\n")
for i in range(start, end):
    generateDataA1.main(i)
# Out:
# generating paths 190 to 208...
#
#
# pos: (-0.383847890086606, -0.23198409691322452), yaw: 0.09153925297575946
# goal: (6.447797802495327, -4.187852406825481)
#
#
# Iterations: 300, Epochs: 10, Episodes: 100, Horizon: 50
#
#
# training data destination: ./trainingData/iter_300_epochs_10_episodes_100_horizon_50/
#
# Running Iteration 0 ...
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Running Iteration 1 ...
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Running Iteration 2 ...
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Running Iteration 3 ...
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Running Iteration 4 ...
# Epoch 0
# Epoch 1
# Epoch 2
# Epoch 3
# Epoch 4
# Epoch 5
# Epoch 6
# Epoch 7
# Epoch 8
# Epoch 9
# Running Iteration 5 ...
# Epoch 0
# Epoch 1
# ...
